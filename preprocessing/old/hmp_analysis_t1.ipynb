# %%
from os import path, listdir
from mne import io, read_epochs
import hmp
import xarray as xr
import pandas as pd
import statsmodels.formula.api as smf

# %%
# Sampling rate. Downsampling to 250Hz is less computationally intensive, but loses some (but minimal) detail compared to 500Hz.
sfreq = 250

data_path = path.join('C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/') # Change to folder where data is located
participant_lim = 0
subj_names = []

# Extracting subject name based on the file name
for x in listdir(data_path):
    if participant_lim >= 23: # In case you only want a few participants
        break

    # Only listing files of Task 1
    if '_t1.fif' in x:
        subj_names.append(x.split('.')[0])
        participant_lim += 1

# Create a list of files that can be read from the folder
subj_files = [data_path+x+'.fif' for x in subj_names]

# %%
#Turning verbose off for the documentation but it is recommended to leave it on as some output from MNE might be useful
hmp.utils.read_mne_data(subj_files, epoched=True, sfreq=sfreq, verbose=False, subj_idx=subj_names, rt_col='rt', reference='average', 
                        lower_limit_RT=.2, low_pass=50, offset_after_resp=0.05).to_netcdf(data_path+'Data_t1_250Hz.nc')
# Out:
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP10_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP10_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1269 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP10_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP11_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP11_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1164 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP11_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP12_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP12_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 889 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP12_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP13_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP13_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1258 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP13_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP14_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP14_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1282 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP14_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP15_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP15_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1285 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP15_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP16_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP16_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1275 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP16_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP17_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP17_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 916 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP17_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP18_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP18_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1251 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP18_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP19_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP19_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1250 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP19_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP1_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP1_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 915 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP1_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP20_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP20_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1159 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP20_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP21_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP21_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1272 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP21_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP22_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP22_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1227 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP22_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP23_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP23_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1218 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP23_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP24_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP24_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1250 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP24_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP2_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP2_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1267 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP2_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP3_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP3_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1268 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP3_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP5_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP5_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1208 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP5_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP8_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP8_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1145 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP8_epo_t1.fif
# Processing participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP9_epo_t1.fif's epoched eeg
# C:\Users\annad\Documents\Thesis\hmp\hmp\utils.py:241: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP9_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(participant, preload=True, verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1226 trials were retained for participant C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP9_epo_t1.fif

# %%
# When using multiple CPUs explicitely setting the context of the multiprocessing is needed. The following line works in most environment
# mp.set_start_method("spawn")

# If multiprocessing errors/warning still present, comment previous line and uncomment this one
# mp.set_start_method("fork")
cpus = 5

# Load epochs from folder
epoch_data = xr.open_dataset(data_path+'Data_t1_250Hz.nc')

# Get channel information from the first participant
info = io.read_info(subj_files[0], verbose=False)

print(epoch_data)
info

# The following code is just to illustrate channel positions
single_epoch = read_epochs(subj_files[0])
single_epoch.plot_sensors(show_names=True);
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:      (participant: 21, epochs: 1315, channels: 64, samples: 500)
# Coordinates:
#   * epochs       (epochs) int32 5kB 0 1 2 3 4 5 ... 1310 1311 1312 1313 1315
#   * channels     (channels) <U3 768B 'Fp1' 'AF7' 'AF3' 'F1' ... 'PO8' 'PO4' 'O2'
#   * samples      (samples) int32 2kB 0 1 2 3 4 5 6 ... 494 495 496 497 498 499
#     rt           (participant, epochs) float64 221kB ...
#     condition    (participant, epochs) <U5 552kB ...
#     trial_index  (participant, epochs) float64 221kB ...
#   * participant  (participant) <U11 924B 'VP10_epo_t1' ... 'VP9_epo_t1'
# Data variables:
#     data         (participant, epochs, channels, samples) float64 7GB ...
# Attributes:
#     sfreq:           250.0
#     offset:          12
#     lowpass:         50.0
#     highpass:        1.0
#     lower_limit_RT:  0.2
#     upper_limit_RT:  1.9520000000000002
# Reading C:\Users\annad\Documents\Thesis\Data\Stimlocked_fixed_index\VP10_epo_t1.fif ...
# C:\Users\annad\AppData\Local\Temp\ipykernel_31340\1459556230.py:18: RuntimeWarning: This filename (C:/Users/annad/Documents/Thesis/Data/Stimlocked_fixed_index/VP10_epo_t1.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   single_epoch = read_epochs(subj_files[0])
#     Found the data of interest:
#         t =    -250.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 3 columns
# 1287 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
# Transform data and set variables
hmp_data = hmp.utils.transform_data(epoch_data, apply_zscore='all', n_comp=10)
event_width = 40

# %%
# Select data where the SOA is long
hmp_data_long_soa = hmp.utils.condition_selection(hmp_data, epoch_data, 'long', variable='condition')
model_init_long = hmp.models.hmp(hmp_data_long_soa, epoch_data, sfreq=epoch_data.sfreq, cpus=cpus, event_width=event_width)

# Estimate maximal model using fit
max_model_long = model_init_long.fit()
# Out:
#   0%|          | 0/154 [00:00<?, ?it/s]
# Transition event 1 found around sample 12
# Transition event 2 found around sample 50
# Transition event 3 found around sample 108
# Transition event 4 found around sample 138
#
# All events found, refitting final combination.
# Estimating 4 events model
# parameters estimated for 4 events model

# %%
# Select data where the SOA is short
hmp_data_short_soa = hmp.utils.condition_selection(hmp_data, epoch_data, 'short', variable='condition')
model_init_short = hmp.models.hmp(hmp_data_short_soa, epoch_data, sfreq=epoch_data.sfreq, cpus=cpus, event_width=event_width)

# Estimate maximal model using fit
max_model_short = model_init_short.fit()
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
# Transition event 1 found around sample 11
# Transition event 2 found around sample 50
# Transition event 3 found around sample 120
# Transition event 4 found around sample 144
#
# All events found, refitting final combination.
# Estimating 4 events model
# parameters estimated for 4 events model

# %%
# save fit
hmp.utils.save_fit(max_model_long, data_path+'fit_t1_long_250_ew40.nc')
hmp.utils.save_fit(max_model_short, data_path+'fit_t1_short_250_ew40.nc')
# Out:
# C:/Users/annad/Documents/Thesis/Data/Stimuluslocked_tryoutv3/fit_t1_long_250_off50.nc saved
# C:/Users/annad/Documents/Thesis/Data/Stimuluslocked_tryoutv3/fit_t1_short_250_off50.nc saved

# %%
# Plot fit
hmp.visu.plot_topo_timecourse(epoch_data, max_model_long, info, model_init_long, as_time=True, max_time=800)
hmp.visu.plot_topo_timecourse(epoch_data, max_model_short, info, model_init_short, as_time=True, max_time=800)

# %%
# Use backwards estimation to validate model LONG
backward_model = model_init_long.backward_estimation(max_fit=max_model_long)
hmp.visu.plot_topo_timecourse(epoch_data, backward_model, info, model_init_long)
# Out:
# Estimating all solutions for 2 events
# Estimating all solutions for 1 events

# %%
# Use LOOCV to validate generalisation
loocv_model = hmp.loocv.loocv(model_init_long, hmp_data_long_soa, backward_model, print_warning=False)

# Colored shaded lines represent individuals
hmp.visu.plot_loocv(loocv_model, pvals=True, test='sign', indiv=True, mean=True)
# Out:
# LOOCV started for 1 model(s)
# 	LOOCV for backward estimation models with [3 2 1] event(s)
# 	  Estimating backward estimation model with 3 event(s)
# 		Calculating fit for participant VP22_epo_t1
# 		Calculating fit for participant VP23_epo_t1
# 		Calculating fit for participant VP24_epo_t1
# 		Calculating fit for participant VP2_epo_t1
# 		Calculating fit for participant VP3_epo_t1
# 		Calculating fit for participant VP5_epo_t1
# 		Calculating fit for participant VP8_epo_t1
# 		Calculating fit for participant VP9_epo_t1
# 	  Estimating backward estimation model with 2 event(s)
# 		Calculating fit for participant VP22_epo_t1
# 		Calculating fit for participant VP23_epo_t1
# 		Calculating fit for participant VP24_epo_t1
# 		Calculating fit for participant VP2_epo_t1
# 		Calculating fit for participant VP3_epo_t1
# 		Calculating fit for participant VP5_epo_t1
# 		Calculating fit for participant VP8_epo_t1
# 		Calculating fit for participant VP9_epo_t1
# 	  Estimating backward estimation model with 1 event(s)
# 		Calculating fit for participant VP22_epo_t1
# 		Calculating fit for participant VP23_epo_t1
# 		Calculating fit for participant VP24_epo_t1
# 		Calculating fit for participant VP2_epo_t1
# 		Calculating fit for participant VP3_epo_t1
# 		Calculating fit for participant VP5_epo_t1
# 		Calculating fit for participant VP8_epo_t1
# 		Calculating fit for participant VP9_epo_t1

# %%
# Get stage durations per trial
times_short = hmp.models.hmp.compute_times(model_init_short, max_model_short, duration=True, as_time=True, onset=True, add_rt=True)
times_long = hmp.models.hmp.compute_times(model_init_long, max_model_long, duration=True, as_time=True, onset=True, add_rt=True)

df_short = times_short.to_dataframe().drop(columns=['component']).reset_index(drop=True)
df_long = times_long.to_dataframe().drop(columns=['component']).reset_index(drop=True)

# Add column with stage numbers and condition
df_short['event'] = (df_short.index % 5) + 1
df_long['event'] = (df_long.index % 5) + 1
df_short["condition"] = "short"
df_long["condition"] = "long"

data = pd.concat([df_short, df_long], ignore_index=True)
data.columns = ['participant', 'trial', 'duration', 'event', 'condition'] # Change column names for consistency
data['event'] = data['event'].astype('category') # To make sure the mixed model sees the values as a categories

print(data)
data.to_csv('event_durations_t1.csv', index=False)

# %%
# Create Mixed Linear Model to statistically test stage durations
model = smf.mixedlm("duration ~ condition * event", data, groups=data['participant'])
result = model.fit()

p_values = result.pvalues
print(result.summary())
print(result.pvalues)
# Out:
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                  MixedLM       Dependent Variable:       duration
# No. Observations:       120460        Method:                   REML
# No. Groups:             21            Scale:                    7506.0099
# Min. group size:        4165          Log-Likelihood:           -708433.1581
# Max. group size:        6325          Converged:                Yes
# Mean group size:        5736.2
# ----------------------------------------------------------------------------
#                                Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------------------
# Intercept                       0.161    5.011   0.032 0.974  -9.659   9.982
# condition[T.short]              0.732    1.116   0.656 0.512  -1.456   2.921
# event[T.2]                    115.053    1.117 103.003 0.000 112.864 117.242
# event[T.3]                    258.754    1.117 231.652 0.000 256.565 260.943
# event[T.4]                    195.890    1.117 175.372 0.000 193.700 198.079
# event[T.5]                     52.699    1.117  47.179 0.000  50.510  54.888
# condition[T.short]:event[T.2]   5.853    1.579   3.708 0.000   2.759   8.948
# condition[T.short]:event[T.3]  22.885    1.579  14.496 0.000  19.791  25.980
# condition[T.short]:event[T.4] -18.396    1.579 -11.652 0.000 -21.490 -15.302
# condition[T.short]:event[T.5]  -4.791    1.579  -3.035 0.002  -7.886  -1.697
# Group Var                     514.102    1.890
# ============================================================================
#
# Intercept                        9.743473e-01
# condition[T.short]               5.119362e-01
# event[T.2]                       0.000000e+00
# event[T.3]                       0.000000e+00
# event[T.4]                       0.000000e+00
# event[T.5]                       0.000000e+00
# condition[T.short]:event[T.2]    2.092842e-04
# condition[T.short]:event[T.3]    1.285171e-47
# condition[T.short]:event[T.4]    2.233080e-31
# condition[T.short]:event[T.5]    2.406194e-03
# Group Var                        1.686954e-03
# dtype: float64

# %%
# Get event onset times per trial (used when cropping epochs to event width)
times_short = hmp.models.hmp.compute_times(model_init_short, max_model_short, as_time=True, onset=True)
times_long = hmp.models.hmp.compute_times(model_init_long, max_model_long, as_time=True, onset=True)

df_short = times_short.to_dataframe().reset_index(drop=True)
df_long = times_long.to_dataframe().reset_index(drop=True)

# Add column with event numbers and condition
df_short['event'] = (df_short.index % 4) + 1
df_long['event'] = (df_long.index % 4) + 1
df_short["condition"] = "short"
df_long["condition"] = "long"

# Change column names for consistency
df_long.columns = ['participant', 'trial', 'onset', 'event', 'condition']
df_short.columns = ['participant', 'trial', 'onset', 'event', 'condition']

df_long.to_csv('event_onset_long_t1.csv', index=False)
df_short.to_csv('event_onset_short_t1.csv', index=False)
