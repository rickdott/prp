# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import hmp
from pathlib import Path
import os
import xarray as xr
from tqdm.notebook import tqdm
DATA_PATH = Path(os.getenv("DATA_PATH"))

# %% [markdown]
# ### Task 1

# %%
sfreq = 250  # For resampling

eeg_path = DATA_PATH / "prp/epoched_static"
subj_names = [
    x.split("_")[0].split("-")[0] for x in os.listdir(eeg_path) if "t1" in x
] 
subj_names = [subj for subj in subj_names if subj not in ["VP6", "VP7"]]
subj_names.sort()

subj_files = [str(eeg_path) + "/" + x + "-t1-epo.fif" for x in subj_names]

# %%
epoch_data = hmp.utils.read_mne_data(
    subj_files,
    epoched=True,
    sfreq=sfreq,
    rt_col='rt',
    scale=1,
    lower_limit_RT=0.2,
    # reject_threshold=1e-4,
    high_pass=1,
    low_pass=50,
    reference='average',
    verbose=False,
    subj_idx=subj_names,
    # offset_after_resp=0.30,
    # offset_before_stim=0.25,
)
tmp_offset = epoch_data.offset
# epoch_data = epoch_data.assign_attrs({'offset': 0, 'extra_offset': tmp_offset})
epoch_data = epoch_data.assign_attrs({'offset': 0, 'extra_offset': 0})
# hmp.utils.read_mne_data(subj_files, epoched=True, sfreq=sfreq, verbose=False, subj_idx=subj_names, rt_col='rt', reference='average', 
#                         lower_limit_RT=.2, low_pass=50, offset_after_resp=0.05).to_netcdf(data_path+'Data_t1_250Hz.nc')
epoch_data['correct'] = epoch_data.correct.astype(float)
# Out:
# Processing participant /workspace/data_local/prp/epoched_static/VP1-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 824 trials were retained for participant /workspace/data_local/prp/epoched_static/VP1-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP10-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1214 trials were retained for participant /workspace/data_local/prp/epoched_static/VP10-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP11-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1204 trials were retained for participant /workspace/data_local/prp/epoched_static/VP11-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP12-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 821 trials were retained for participant /workspace/data_local/prp/epoched_static/VP12-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP13-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1022 trials were retained for participant /workspace/data_local/prp/epoched_static/VP13-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP14-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1232 trials were retained for participant /workspace/data_local/prp/epoched_static/VP14-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP15-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1245 trials were retained for participant /workspace/data_local/prp/epoched_static/VP15-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP16-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1261 trials were retained for participant /workspace/data_local/prp/epoched_static/VP16-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP17-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 910 trials were retained for participant /workspace/data_local/prp/epoched_static/VP17-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP18-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1195 trials were retained for participant /workspace/data_local/prp/epoched_static/VP18-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP19-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1141 trials were retained for participant /workspace/data_local/prp/epoched_static/VP19-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP2-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1209 trials were retained for participant /workspace/data_local/prp/epoched_static/VP2-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP20-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1127 trials were retained for participant /workspace/data_local/prp/epoched_static/VP20-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP21-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1184 trials were retained for participant /workspace/data_local/prp/epoched_static/VP21-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP22-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1189 trials were retained for participant /workspace/data_local/prp/epoched_static/VP22-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP23-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1168 trials were retained for participant /workspace/data_local/prp/epoched_static/VP23-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP24-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1203 trials were retained for participant /workspace/data_local/prp/epoched_static/VP24-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP3-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1206 trials were retained for participant /workspace/data_local/prp/epoched_static/VP3-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP5-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1185 trials were retained for participant /workspace/data_local/prp/epoched_static/VP5-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP8-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 990 trials were retained for participant /workspace/data_local/prp/epoched_static/VP8-t1-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP9-t1-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1189 trials were retained for participant /workspace/data_local/prp/epoched_static/VP9-t1-epo.fif

# %%
epoch_data.to_netcdf(DATA_PATH / 'prp/data_t1_250hz_static.nc')

# %% [markdown]
# ### Task 2

# %%
sfreq = 250  # For resampling

eeg_path = DATA_PATH / "prp/epoched_static"
subj_names = [
    x.split("_")[0].split("-")[0] for x in os.listdir(eeg_path) if "t2" in x
] 
subj_names = [subj for subj in subj_names if subj not in ["VP6", "VP7"]]
subj_names.sort()

subj_files = [str(eeg_path) + "/" + x + "-t2-epo.fif" for x in subj_names]

# %%
epoch_data = hmp.utils.read_mne_data(
    subj_files,
    epoched=True,
    sfreq=sfreq,
    rt_col='rt',
    scale=1,
    lower_limit_RT=0.2,
    # reject_threshold=1e-4,
    high_pass=1,
    low_pass=50,
    reference='average',
    verbose=False,
    subj_idx=subj_names,
    # offset_after_resp=0.30,
    # offset_before_stim=0.25,
)
tmp_offset = epoch_data.offset
# epoch_data = epoch_data.assign_attrs({'offset': 0, 'extra_offset': tmp_offset})
epoch_data = epoch_data.assign_attrs({'offset': 0, 'extra_offset': 0})
epoch_data['correct'] = epoch_data.correct.astype(float)
# Out:
# Processing participant /workspace/data_local/prp/epoched_static/VP1-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 851 trials were retained for participant /workspace/data_local/prp/epoched_static/VP1-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP10-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1192 trials were retained for participant /workspace/data_local/prp/epoched_static/VP10-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP11-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1161 trials were retained for participant /workspace/data_local/prp/epoched_static/VP11-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP12-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 591 trials were retained for participant /workspace/data_local/prp/epoched_static/VP12-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP13-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1022 trials were retained for participant /workspace/data_local/prp/epoched_static/VP13-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP14-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1226 trials were retained for participant /workspace/data_local/prp/epoched_static/VP14-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP15-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1238 trials were retained for participant /workspace/data_local/prp/epoched_static/VP15-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP16-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1254 trials were retained for participant /workspace/data_local/prp/epoched_static/VP16-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP17-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 873 trials were retained for participant /workspace/data_local/prp/epoched_static/VP17-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP18-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1194 trials were retained for participant /workspace/data_local/prp/epoched_static/VP18-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP19-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1155 trials were retained for participant /workspace/data_local/prp/epoched_static/VP19-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP2-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1194 trials were retained for participant /workspace/data_local/prp/epoched_static/VP2-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP20-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1107 trials were retained for participant /workspace/data_local/prp/epoched_static/VP20-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP21-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1163 trials were retained for participant /workspace/data_local/prp/epoched_static/VP21-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP22-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1178 trials were retained for participant /workspace/data_local/prp/epoched_static/VP22-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP23-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1156 trials were retained for participant /workspace/data_local/prp/epoched_static/VP23-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP24-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1196 trials were retained for participant /workspace/data_local/prp/epoched_static/VP24-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP3-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1204 trials were retained for participant /workspace/data_local/prp/epoched_static/VP3-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP5-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1189 trials were retained for participant /workspace/data_local/prp/epoched_static/VP5-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP8-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1050 trials were retained for participant /workspace/data_local/prp/epoched_static/VP8-t2-epo.fif
# Processing participant /workspace/data_local/prp/epoched_static/VP9-t2-epo.fif's epoched eeg
# /workspace/hmp_repo/hmp/utils.py:254: RuntimeWarning: filter_length (1691) is longer than the signal (1153), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs.filter(high_pass, low_pass, fir_design='firwin', verbose=verbose)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 1177 trials were retained for participant /workspace/data_local/prp/epoched_static/VP9-t2-epo.fif

# %%
epoch_data.to_netcdf(DATA_PATH / 'prp/data_t2_250hz_static.nc')

# %% [markdown]
# ### Combined

# %%
sfreq = 250  # For resampling

eeg_path = DATA_PATH / "prp/epoched"
subj_names = [
    x.split("_")[0].split("-")[0] for x in os.listdir(eeg_path) if "t1" in x
] 
subj_names = [subj for subj in subj_names if subj not in ["VP6", "VP7"]]
subj_names.sort()

subj_files = [str(eeg_path) + "/" + x + "-t-epo.fif" for x in subj_names]

# %%
epoch_data = hmp.utils.read_mne_data(
    subj_files,
    epoched=True,
    sfreq=sfreq,
    rt_col='rt',
    scale=1,
    lower_limit_RT=0.2,
    # reject_threshold=1e-4,
    upper_limit_RT=4, # Manually set here since tmax-offset is used otherwise
    high_pass=1,
    low_pass=50,
    reference='average',
    verbose=True,
    subj_idx=subj_names,
    offset_after_resp=0.30,
    offset_before_stim=0.25,
)
tmp_offset = epoch_data.offset
# epoch_data = epoch_data.assign_attrs({'offset': 0, 'extra_offset': tmp_offset})
epoch_data = epoch_data.assign_attrs({'offset': 12, 'extra_offset': tmp_offset - 12})

# %%
epoch_data['correct_t1'] = epoch_data.correct_t1.astype(float)
epoch_data['correct_t2'] = epoch_data.correct_t2.astype(float)
epoch_data.to_netcdf(DATA_PATH / 'prp/data_t_250hz.nc')

# %% [markdown]
# ### Post-hoc baseline correction
# So that T1 samples are not used to baseline-correct T2

# %%
data_t1 = xr.load_dataset(DATA_PATH / 'prp/data_t1_250hz.nc')
data_t2 = xr.load_dataset(DATA_PATH / 'prp/data_t2_250hz.nc')

# %%
data_t1.sel(epochs=0, participant="VP1").data
# Out:
# <xarray.DataArray 'data' (channels: 64, samples: 561)> Size: 287kB
# array([[ 2.99202846e-06,  4.03018854e-06,  5.72073109e-06, ...,
#                     nan,             nan,             nan],
#        [-3.29227781e-06,  6.30110186e-06,  1.70287745e-05, ...,
#                     nan,             nan,             nan],
#        [ 1.56055191e-06,  6.99560229e-06,  1.19482595e-05, ...,
#                     nan,             nan,             nan],
#        ...,
#        [-4.87555442e-06, -7.86861670e-06, -1.41714511e-05, ...,
#                     nan,             nan,             nan],
#        [-1.55225455e-05, -1.51264982e-05, -1.44201428e-05, ...,
#                     nan,             nan,             nan],
#        [ 2.58870371e-06, -2.75215169e-06, -1.49323577e-05, ...,
#                     nan,             nan,             nan]],
#       shape=(64, 561))
# Coordinates:
#     epochs       int64 8B 0
#   * channels     (channels) <U3 768B 'Fp1' 'AF7' 'AF3' 'F1' ... 'PO8' 'PO4' 'O2'
#   * samples      (samples) int64 4kB 0 1 2 3 4 5 6 ... 555 556 557 558 559 560
#     rt           float64 8B 1.406
#     condition    <U5 20B 'long'
#     trial_index  float64 8B 0.0
#     interval     float64 8B 1.197
#     correct      float64 8B 1.0
#     participant  <U4 16B 'VP1'

# %%
data_t1 = xr.load_dataset(DATA_PATH / 'prp/data_t1_250hz.nc')
data_t2 = xr.load_dataset(DATA_PATH / 'prp/data_t2_250hz.nc')

# Samples before stim onset of t1
baseline_window = slice(0, data_t1.offset_before)

for p in tqdm(data_t1.participant.values):
    data_t1_p = data_t1.sel(participant=[p])
    data_t2_p = data_t2.sel(participant=[p])

    for trial_idx in data_t1_p.trial_index[0].values:
        if np.isnan(trial_idx):
            continue
        data_t1_trial = data_t1_p.where(data_t1_p.trial_index == trial_idx, drop=True)
        baseline = data_t1_trial.sel(samples=baseline_window).data
        channel_means = baseline.mean(axis=3).data
        channel_means = channel_means[..., np.newaxis]
        corrected = data_t1_trial.data - channel_means
        data_t1.data.loc[dict(participant=[p], epochs=[data_t1_trial.epochs.values[0]])].data = corrected
        # BASELINE CORRECT
        if trial_idx not in data_t2_p.trial_index.values:
            continue
        data_t2_trial = data_t2_p.where(data_t2_p.trial_index == trial_idx, drop=True)
        corrected = data_t2_trial.data - channel_means
        data_t2.data.loc[dict(participant=[p], epochs=[data_t2_trial.epochs.values[0]])].data = corrected
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
data_t1.sel(epochs=0, participant="VP1").data
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:      (participant: 21, epochs: 1281, channels: 64, samples: 561)
# Coordinates:
#   * epochs       (epochs) int64 10kB 0 1 2 3 4 5 ... 1276 1277 1278 1279 1280
#   * channels     (channels) <U3 768B 'Fp1' 'AF7' 'AF3' 'F1' ... 'PO8' 'PO4' 'O2'
#   * samples      (samples) int64 4kB 0 1 2 3 4 5 6 ... 555 556 557 558 559 560
#     rt           (participant, epochs) float64 215kB 1.406 0.6855 ... nan nan
#     condition    (participant, epochs) <U5 538kB 'long' 'long' 'short' ... '' ''
#     trial_index  (participant, epochs) float64 215kB 0.0 1.0 2.0 ... nan nan nan
#     interval     (participant, epochs) float64 215kB 1.197 1.178 ... nan nan
#     correct      (participant, epochs) float64 215kB 1.0 1.0 1.0 ... nan nan nan
#   * participant  (participant) <U4 336B 'VP1' 'VP10' 'VP11' ... 'VP8' 'VP9'
# Data variables:
#     data         (participant, epochs, channels, samples) float64 8GB 2.992e-...
# Attributes:
#     sfreq:           250.0
#     offset:          12
#     offset_before:   62
#     lowpass:         50.0
#     highpass:        1.0
#     lower_limit_RT:  0.2
#     upper_limit_RT:  1.7020000000000002
#     extra_offset:    63

# %%
data_t1.sel(epochs=0, participant="VP1").data
# Out:
# <xarray.DataArray 'data' (channels: 64, samples: 561)> Size: 287kB
# array([[ 2.29772244e-06,  3.24830039e-06,  5.24018387e-06, ...,
#                     nan,             nan,             nan],
#        [ 5.36795382e-06,  5.91592979e-06,  5.47080874e-06, ...,
#                     nan,             nan,             nan],
#        [ 8.66245886e-07,  6.21371414e-06,  1.14677123e-05, ...,
#                     nan,             nan,             nan],
#        ...,
#        [ 5.75809082e-07, -3.96353216e-06, -1.86996495e-05, ...,
#                     nan,             nan,             nan],
#        [-1.62168515e-05, -1.59083863e-05, -1.49006900e-05, ...,
#                     nan,             nan,             nan],
#        [-4.99767229e-06, -8.63243326e-06, -1.59184648e-05, ...,
#                     nan,             nan,             nan]],
#       shape=(64, 561))
# Coordinates:
#     epochs       int64 8B 0
#   * channels     (channels) <U3 768B 'Fp1' 'AF7' 'AF3' 'F1' ... 'PO8' 'PO4' 'O2'
#   * samples      (samples) int64 4kB 0 1 2 3 4 5 6 ... 555 556 557 558 559 560
#     rt           float64 8B 1.406
#     condition    <U5 20B 'long'
#     trial_index  float64 8B 0.0
#     interval     float64 8B 1.197
#     correct      float64 8B 1.0
#     participant  <U4 16B 'VP1'

# %%
# SAVE DATA t1 AND DATA t2 AFTER CHECKING IF THEY ARE DIFFERENT

# %%
data_t1.to_netcdf(DATA_PATH / 'prp/data_t1_250hz_baseline.nc')

# %%
data_t2.to_netcdf(DATA_PATH / 'prp/data_t2_250hz_baseline.nc')
